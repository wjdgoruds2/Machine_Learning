# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdgoruds2/Machine_Learning/blob/main/Kmeans_elbow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt #차트 사용 
from sklearn.datasets.samples_generator import make_blobs #덩어리 데이터 
from sklearn.cluster import KMeans #Kmeans군집화

X,Y=make_blobs(n_samples=300,centers=4,cluster_std=0.60,random_state=0) #표준편차가 0.60인 4개의 군집으로 300개의 샘플
plt.scatter(X[:,0],X[:,1]) #산점도 표현
plt.show()

SSEs=[]
for i in range(1,11):#1~10까지 반복
  kmeans=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)#K-means++사용하여 i개의 군집으로 최대 300번 반복,초기중심점 반복회수 10번
  #"K-means++" 는 하나의 무작위 중심점을 배정하고 두번째 중심점을 첫번째 중심점과 멀리 떨어진 곳에 배치, 그리고 다음 중심점을 1,2번째 중심점과 멀리 떨어지도록 배치하는 방식
  kmeans.fit_predict(X) #군집화 수행
  SSEs.append(kmeans.inertia_)#SSE값 저장
plt.plot(range(1,11),SSEs,marker='o')#'o'로 표시후 범위 1~10까지 그래프 표현
plt.show()
